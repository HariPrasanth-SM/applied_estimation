# %% [markdown]
# ## Analysis on 2011_09_26_0023
#
# This notebook analysis the comparison between Extended Kalman Filter (EKF) and Unscented Kalman Filter (UKF) on kitti dataset found on (link)

# %% [markdown]
# ### Import libraries

# %%
import numpy as np
import pykitti
import sys
import matplotlib.pyplot as plt

from read_kitti_data import LoadKittiData
from ExtendedKalmanFilter import ExtendedKalmanFilter
from UnscentedKalmanFilter import UnscentedKalmanFilter
from filter_estimation import Filter_Estimation, apply_estimation_filter
from helper_functions import lla_to_enu, normalize_angles

# %matplotlib inline
np.random.seed(10)

# %% [markdown]
# ### Read file

# %%
kitti_root_dir = '../data/kitti'
kitti_date = '2011_09_26'
kitti_drive = '0023'
kitti_data = LoadKittiData(kitti_root_dir, kitti_date, kitti_drive)

# %% [markdown]
# ## Case 1: low noise

# %% [markdown]
# ### Defining noises

# %%
obs_noise_std=[5, 5, np.pi]
input_noise_std=[0.3, 0.02]

# %%
kitti_data.add_gaussian_noise_observation(obs_noise_std)
kitti_data.add_gaussian_noise_control_input(input_noise_std)

# %% [markdown]
# ### Plot control input data

# %%
kitti_data.plot_control_input_data()

# %% [markdown]
# ### Plot observation data

# %%
kitti_data.plot_observation_data()

# %% [markdown]
# ### Initialising state and covariance

# %%
# initial state x_0
initial_theta_std = np.pi
initial_theta = normalize_angles(np.random.normal(0, initial_theta_std))

x_0 = np.array([
    kitti_data.observation_states[0, 0],
    kitti_data.observation_states[1, 0],
    initial_theta
])
x_0
# Out:
# array([ 6.65793252,  4.32259236, -2.99810206])

# %%
# covariance for initial state estimation error (Sigma_0)
P_0 = np.array([
    [obs_noise_std[0] ** 2., 0., 0.],
    [0., obs_noise_std[1] ** 2., 0.],
    [0., 0., obs_noise_std[2] ** 2.]
])
P_0
# Out:
# array([[25.       ,  0.       ,  0.       ],
#        [ 0.       , 25.       ,  0.       ],
#        [ 0.       ,  0.       ,  9.8696044]])

# %%
# measurement error covariance Q
Q = np.array([
    [obs_noise_std[0] ** 2., 0.],
    [0., obs_noise_std[1] ** 2.]
])
Q
# Out:
# array([[25.,  0.],
#        [ 0., 25.]])

# %%
# 
R = np.array([
    [input_noise_std[0] ** 2., 0., 0.],
    [0., input_noise_std[0] ** 2., 0.],
    [0., 0., input_noise_std[1] ** 2.]
])
R
# Out:
# array([[0.09  , 0.    , 0.    ],
#        [0.    , 0.09  , 0.    ],
#        [0.    , 0.    , 0.0004]])

# %% [markdown]
# ### Extended Kalman Filter

# %%
ekf_estimated_state = apply_estimation_filter(kitti_data, 'EKF', x_0, P_0, R, Q)

# %%
kitti_data.plot_estimated_data(ekf_estimated_state)

# %%
kitti_data.evaluate_filter(ekf_estimated_state)
# Out:
# {'RMSE': array([1.08530054, 1.42241002, 0.16606947]),
#  'MAE': array([0.87000271, 1.08824599, 0.06910545]),
#  'MSE': array([1.17787727, 2.02325028, 0.02757907]),
#  'NRMSE': array([0.00214768, 0.00281478, 0.00032863]),
#  'Mean_Error': array([0.58507015, 0.03692307, 0.01400809]),
#  'Std_Error': array([0.91409529, 1.42193072, 0.16547762]),
#  'Mean_Angular_Error': 0.01400808926974837}

# %% [markdown]
# ### Unscented Kalman Filter

# %%
ukf_estimated_state = apply_estimation_filter(kitti_data, 'UKF', x_0, P_0, R, Q)

# %%
kitti_data.plot_estimated_data(ukf_estimated_state)

# %%
kitti_data.evaluate_filter(ukf_estimated_state)
# Out:
# {'RMSE': array([0.80644069, 3.72638503, 0.32197983]),
#  'MAE': array([0.59867252, 3.53611136, 0.29438839]),
#  'MSE': array([ 0.65034658, 13.88594543,  0.10367101]),
#  'NRMSE': array([0.00159585, 0.00737407, 0.00063716]),
#  'Mean_Error': array([-0.04882215,  3.51625573, -0.29438839]),
#  'Std_Error': array([0.80496148, 1.2336495 , 0.13040892]),
#  'Mean_Angular_Error': -0.29438838652374455}

# %% [markdown]
# ### Compare yaw angle

# %%
timestamps = kitti_data.timestamps
original_yaw_angle = kitti_data.ground_truth_states[2, :]
ekf_estimated = ekf_estimated_state[2, :]
ukf_estimated = ukf_estimated_state[2, :]

fig = plt.figure()
plt.plot(timestamps, original_yaw_angle, lw=2, label="ground-truth")
plt.plot(timestamps, ekf_estimated, marker='.', lw=0, markersize=5, alpha=0.4, label='EKF')
plt.plot(timestamps, ukf_estimated, marker='.', lw=0, markersize=5, alpha=0.4, label='UKF')
plt.xlabel('time elapsed [sec]')
plt.ylabel('yaw angle [rad]')
plt.legend()
#plt.show()
plt.savefig('2011_09_26_0023_01.png', bbox_inches='tight')

# %%
fig, axarr = plt.subplots(1, 2, figsize=(12,5))
ax = axarr[0]
ax.plot(kitti_data.ground_truth_states[0, :], kitti_data.ground_truth_states[1, :], lw=3, label='ground-truth')
ax.plot(kitti_data.observation_states[0, :], kitti_data.observation_states[1, :], lw=0, marker='.', markersize=2, alpha=0.4, label='observed')
ax.plot(ekf_estimated_state[0, :], ekf_estimated_state[1, :], linestyle='dashed', lw=1.5, alpha=0.6, label='EKF estimated trajectory', color='r')
#ax.plot(ukf_estimated_state[0, :], ukf_estimated_state[1, :], linestyle='dashed', lw=1.5, alpha=0.99, label='UKF estimated trajectory', color='g')
ax.set_xlabel('X [m]')
ax.set_ylabel('Y [m]')
#ax.set_ylim([-70, 55])
#ax.set_xlim([-350, 180])
ax.title.set_text('EKF estimation')
ax.grid()
ax.legend()

ax = axarr[1]
ax.plot(kitti_data.ground_truth_states[0, :], kitti_data.ground_truth_states[1, :], lw=3, label='ground-truth')
ax.plot(kitti_data.observation_states[0, :], kitti_data.observation_states[1, :], lw=0, marker='.', markersize=2, alpha=0.4, label='observed')
#ax.plot(ekf_estimated_state[0, :], ekf_estimated_state[1, :], linestyle='dashed', lw=1.5, alpha=0.99, label='EKF estimated trajectory', color='r')
ax.plot(ukf_estimated_state[0, :], ukf_estimated_state[1, :], linestyle='dashed', lw=1.5, alpha=0.6, label='UKF estimated trajectory', color='r')
ax.set_xlabel('X [m]')
ax.set_ylabel('Y [m]')
#ax.set_ylim([-70, 55])
#ax.set_xlim([-350, 180])
ax.title.set_text('UKF estimation')
ax.grid()
ax.legend()

plt.tight_layout()
#plt.show()
plt.savefig('2011_09_26_0023.png', bbox_inches='tight')

# %% [markdown]
# ## Case 2: high noise

# %% [markdown]
# ### Defining noises

# %%
obs_noise_std=[15, 15, np.pi]
input_noise_std=[0.9, 0.06]

# %%
kitti_data.add_gaussian_noise_observation(obs_noise_std)
kitti_data.add_gaussian_noise_control_input(input_noise_std)

# %% [markdown]
# ### Plot control input data

# %%
kitti_data.plot_control_input_data()

# %% [markdown]
# ### Plot observation data

# %%
kitti_data.plot_observation_data()

# %% [markdown]
# ### Initialise state and covariance

# %%
# initial state x_0
initial_theta_std = np.pi
initial_theta = normalize_angles(np.random.normal(0, initial_theta_std))

x_0 = np.array([
    kitti_data.observation_states[0, 0],
    kitti_data.observation_states[1, 0],
    initial_theta
])
x_0
# Out:
# array([11.92258874, -6.13137684, -0.16747117])

# %%
# covariance for initial state estimation error (Sigma_0)
P_0 = np.array([
    [obs_noise_std[0] ** 2., 0., 0.],
    [0., obs_noise_std[1] ** 2., 0.],
    [0., 0., obs_noise_std[2] ** 2.]
])
P_0
# Out:
# array([[225.       ,   0.       ,   0.       ],
#        [  0.       , 225.       ,   0.       ],
#        [  0.       ,   0.       ,   9.8696044]])

# %%
# measurement error covariance Q
Q = np.array([
    [obs_noise_std[0] ** 2., 0.],
    [0., obs_noise_std[1] ** 2.]
])
Q
# Out:
# array([[225.,   0.],
#        [  0., 225.]])

# %%
#
R = np.array([
    [input_noise_std[0] ** 2., 0., 0.],
    [0., input_noise_std[0] ** 2., 0.],
    [0., 0., input_noise_std[1] ** 2.]
])
R
# Out:
# array([[0.81  , 0.    , 0.    ],
#        [0.    , 0.81  , 0.    ],
#        [0.    , 0.    , 0.0036]])

# %% [markdown]
# ### Extended Kalman Filter

# %%
ekf_estimated_state = apply_estimation_filter(kitti_data, 'EKF', x_0, P_0, R, Q)

# %%
kitti_data.plot_estimated_data(ekf_estimated_state)

# %%
kitti_data.evaluate_filter(ekf_estimated_state)
# Out:
# {'RMSE': array([3.0479697 , 4.18922528, 0.35893132]),
#  'MAE': array([2.32214332, 3.37475431, 0.18933955]),
#  'MSE': array([ 9.29011929, 17.54960843,  0.12883169]),
#  'NRMSE': array([0.00603156, 0.00828997, 0.00071028]),
#  'Mean_Error': array([ 0.57016059, -0.26645189,  0.07552428]),
#  'Std_Error': array([2.99416703, 4.18074298, 0.35089567]),
#  'Mean_Angular_Error': 0.07552428256769991}

# %% [markdown]
# ### Unscented Kalman Filter

# %%
ukf_estimated_state = apply_estimation_filter(kitti_data, 'UKF', x_0, P_0, R, Q)

# %%
kitti_data.plot_estimated_data(ukf_estimated_state)

# %%
kitti_data.evaluate_filter(ukf_estimated_state)
# Out:
# {'RMSE': array([17.16620913,  7.85033031,  1.91042673]),
#  'MAE': array([16.59288694,  7.04345578,  1.89924136]),
#  'MSE': array([294.67873579,  61.62768593,   3.64973029]),
#  'NRMSE': array([0.03396986, 0.01553486, 0.0037805 ]),
#  'Mean_Error': array([-16.1671179 ,  -6.57944036,   1.89924136]),
#  'Std_Error': array([5.77087816, 4.28236506, 0.20642804]),
#  'Mean_Angular_Error': 1.8992413631411549}

# %% [markdown]
# ### Compare yaw angle

# %%
timestamps = kitti_data.timestamps
original_yaw_angle = kitti_data.ground_truth_states[2, :]
ekf_estimated = ekf_estimated_state[2, :]
ukf_estimated = ukf_estimated_state[2, :]

fig = plt.figure()
plt.plot(timestamps, original_yaw_angle, lw=2, label="ground-truth")
plt.plot(timestamps, ekf_estimated, marker='.', lw=0, markersize=5, alpha=0.4, label='EKF')
plt.plot(timestamps, ukf_estimated, marker='.', lw=0, markersize=5, alpha=0.4, label='UKF')
plt.xlabel('time elapsed [sec]')
plt.ylabel('yaw angle [rad]')
plt.legend()
#plt.show()
plt.savefig('2011_09_26_0023_02.png', bbox_inches='tight')

# %%
fig, axarr = plt.subplots(1, 2, figsize=(12,5))
ax = axarr[0]
ax.plot(kitti_data.ground_truth_states[0, :], kitti_data.ground_truth_states[1, :], lw=3, label='ground-truth')
ax.plot(kitti_data.observation_states[0, :], kitti_data.observation_states[1, :], lw=0, marker='.', markersize=2, alpha=0.4, label='observed')
ax.plot(ekf_estimated_state[0, :], ekf_estimated_state[1, :], linestyle='dashed', lw=1.5, alpha=0.6, label='EKF estimated trajectory', color='r')
#ax.plot(ukf_estimated_state[0, :], ukf_estimated_state[1, :], linestyle='dashed', lw=1.5, alpha=0.99, label='UKF estimated trajectory', color='g')
ax.set_xlabel('X [m]')
ax.set_ylabel('Y [m]')
#ax.set_ylim([-70, 55])
#ax.set_xlim([-350, 180])
ax.title.set_text('EKF estimation')
ax.grid()
ax.legend()

ax = axarr[1]
ax.plot(kitti_data.ground_truth_states[0, :], kitti_data.ground_truth_states[1, :], lw=3, label='ground-truth')
ax.plot(kitti_data.observation_states[0, :], kitti_data.observation_states[1, :], lw=0, marker='.', markersize=2, alpha=0.4, label='observed')
#ax.plot(ekf_estimated_state[0, :], ekf_estimated_state[1, :], linestyle='dashed', lw=1.5, alpha=0.99, label='EKF estimated trajectory', color='r')
ax.plot(ukf_estimated_state[0, :], ukf_estimated_state[1, :], linestyle='dashed', lw=1.5, alpha=0.6, label='UKF estimated trajectory', color='r')
ax.set_xlabel('X [m]')
ax.set_ylabel('Y [m]')
#ax.set_ylim([-70, 55])
#ax.set_xlim([-350, 180])
ax.title.set_text('UKF estimation')
ax.grid()
ax.legend()

plt.tight_layout()
#plt.show()
plt.savefig('2011_09_26_0023_04.png', bbox_inches='tight')

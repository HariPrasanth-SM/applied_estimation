# %% [markdown]
# ## Analysis on 2011_09_30_0034
#
# This notebook analysis the comparison between Extended Kalman Filter (EKF) and Unscented Kalman Filter (UKF) on kitti dataset found on (link)

# %% [markdown]
# ### Import libraries

# %%
import numpy as np
import pykitti
import sys
import matplotlib.pyplot as plt

from read_kitti_data import LoadKittiData
from ExtendedKalmanFilter import ExtendedKalmanFilter
from UnscentedKalmanFilter import UnscentedKalmanFilter
from filter_estimation import Filter_Estimation, apply_estimation_filter
from helper_functions import lla_to_enu, normalize_angles

# %matplotlib inline
np.random.seed(10)

# %% [markdown]
# ### Read file

# %%
kitti_root_dir = '../data/kitti'
kitti_date = '2011_09_30'
kitti_drive = '0034'
kitti_data = LoadKittiData(kitti_root_dir, kitti_date, kitti_drive)

# %% [markdown]
# ## Case 1: low noise

# %% [markdown]
# ### Defining the noise

# %%
obs_noise_std=[5, 5, np.pi]
input_noise_std=[0.3, 0.02]

# %%
kitti_data.add_gaussian_noise_observation(obs_noise_std)
kitti_data.add_gaussian_noise_control_input(input_noise_std)

# %% [markdown]
# ### Plot of control input data

# %%
kitti_data.plot_control_input_data()

# %% [markdown]
# ### Plot of observation data

# %%
kitti_data.plot_observation_data()

# %% [markdown]
# ### Initialising state and covariance

# %%
# initial state x_0
initial_theta_std = np.pi
initial_theta = normalize_angles(np.random.normal(0, initial_theta_std))

x_0 = np.array([
    kitti_data.observation_states[0, 0],
    kitti_data.observation_states[1, 0],
    initial_theta
])
x_0
# Out:
# array([6.65793252, 2.08676909, 1.83161182])

# %%
# covariance for initial state estimation error (Sigma_0)
P_0 = np.array([
    [obs_noise_std[0] ** 2., 0., 0.],
    [0., obs_noise_std[1] ** 2., 0.],
    [0., 0., obs_noise_std[2] ** 2.]
])
P_0
# Out:
# array([[25.       ,  0.       ,  0.       ],
#        [ 0.       , 25.       ,  0.       ],
#        [ 0.       ,  0.       ,  9.8696044]])

# %%
# measurement error covariance Q
Q = np.array([
    [obs_noise_std[0] ** 2., 0.],
    [0., obs_noise_std[1] ** 2.]
])
Q
# Out:
# array([[25.,  0.],
#        [ 0., 25.]])

# %%
# 
R = np.array([
    [input_noise_std[0] ** 2., 0., 0.],
    [0., input_noise_std[0] ** 2., 0.],
    [0., 0., input_noise_std[1] ** 2.]
])
R
# Out:
# array([[0.09  , 0.    , 0.    ],
#        [0.    , 0.09  , 0.    ],
#        [0.    , 0.    , 0.0004]])

# %% [markdown]
# ### Extended Kalman Filter

# %%
ekf_estimated_state = apply_estimation_filter(kitti_data, 'EKF', x_0, P_0, R, Q)

# %%
kitti_data.plot_estimated_data(ekf_estimated_state)

# %%
kitti_data.evaluate_filter(ekf_estimated_state)
# Out:
# {'RMSE': array([0.91165889, 0.87293272, 0.16386205]),
#  'MAE': array([0.73333063, 0.69734777, 0.05695596]),
#  'MSE': array([0.83112194, 0.76201154, 0.02685077]),
#  'NRMSE': array([0.00133905, 0.00128217, 0.00024068]),
#  'Mean_Error': array([-0.00097051,  0.08483303, -0.02069557]),
#  'Std_Error': array([0.91165838, 0.86880084, 0.16254988]),
#  'Mean_Angular_Error': -0.02069557108789343}

# %% [markdown]
# ### Unscented Kalman Filter

# %%
ukf_estimated_state = apply_estimation_filter(kitti_data, 'UKF', x_0, P_0, R, Q)

# %%
kitti_data.plot_estimated_data(ukf_estimated_state)

# %%
kitti_data.evaluate_filter(ukf_estimated_state)
# Out:
# {'RMSE': array([1.02852294, 0.90441736, 0.6570513 ]),
#  'MAE': array([0.81393951, 0.72119466, 0.40867106]),
#  'MSE': array([1.05785943, 0.81797077, 0.43171641]),
#  'NRMSE': array([0.0015107 , 0.00132841, 0.00096508]),
#  'Mean_Error': array([-0.37531749, -0.09217506, -0.40867106]),
#  'Std_Error': array([0.95759919, 0.89970802, 0.51449429]),
#  'Mean_Angular_Error': -0.40867105950564225}

# %% [markdown]
# ### Compare yaw angle

# %%
timestamps = kitti_data.timestamps
original_yaw_angle = kitti_data.ground_truth_states[2, :]
ekf_estimated = ekf_estimated_state[2, :]
ukf_estimated = ukf_estimated_state[2, :]

fig = plt.figure()
plt.plot(timestamps, original_yaw_angle, lw=2, label="ground-truth")
plt.plot(timestamps, ekf_estimated, marker='.', lw=0, markersize=5, alpha=0.4, label='EKF')
plt.plot(timestamps, ukf_estimated, marker='.', lw=0, markersize=5, alpha=0.4, label='UKF')
plt.xlabel('time elapsed [sec]')
plt.ylabel('yaw angle [rad]')
plt.legend()
plt.savefig('2011_09_30_0034_01.png', bbox_inches='tight')
#plt.show()

# %%
fig, axarr = plt.subplots(1, 2, figsize=(12,5))
ax = axarr[0]
ax.plot(kitti_data.ground_truth_states[0, :], kitti_data.ground_truth_states[1, :], lw=3, label='ground-truth')
ax.plot(kitti_data.observation_states[0, :], kitti_data.observation_states[1, :], lw=0, marker='.', markersize=2, alpha=0.4, label='observed')
ax.plot(ekf_estimated_state[0, :], ekf_estimated_state[1, :], linestyle='dashed', lw=1.5, alpha=0.6, label='EKF estimated trajectory', color='r')
#ax.plot(ukf_estimated_state[0, :], ukf_estimated_state[1, :], linestyle='dashed', lw=1.5, alpha=0.99, label='UKF estimated trajectory', color='g')
ax.set_xlabel('X [m]')
ax.set_ylabel('Y [m]')
#ax.set_ylim([-70, 55])
#ax.set_xlim([-350, 180])
ax.title.set_text('EKF estimation')
ax.grid()
ax.legend()

ax = axarr[1]
ax.plot(kitti_data.ground_truth_states[0, :], kitti_data.ground_truth_states[1, :], lw=3, label='ground-truth')
ax.plot(kitti_data.observation_states[0, :], kitti_data.observation_states[1, :], lw=0, marker='.', markersize=2, alpha=0.4, label='observed')
#ax.plot(ekf_estimated_state[0, :], ekf_estimated_state[1, :], linestyle='dashed', lw=1.5, alpha=0.99, label='EKF estimated trajectory', color='r')
ax.plot(ukf_estimated_state[0, :], ukf_estimated_state[1, :], linestyle='dashed', lw=1.5, alpha=0.6, label='UKF estimated trajectory', color='r')
ax.set_xlabel('X [m]')
ax.set_ylabel('Y [m]')
#ax.set_ylim([-70, 55])
#ax.set_xlim([-350, 180])
ax.title.set_text('UKF estimation')
ax.grid()
ax.legend()

plt.tight_layout()
#plt.show()
plt.savefig('2011_09_30_0034.png', bbox_inches='tight')

# %% [markdown]
# ## Case 2: high noise

# %% [markdown]
# ### Defining noises

# %%
obs_noise_std=[15, 15, np.pi]
input_noise_std=[0.9, 0.06]

# %%
kitti_data.add_gaussian_noise_observation(obs_noise_std)
kitti_data.add_gaussian_noise_control_input(input_noise_std)

# %% [markdown]
# ### Plot control input data

# %%
kitti_data.plot_control_input_data()

# %% [markdown]
# ### Plot observation data

# %%
kitti_data.plot_observation_data()

# %% [markdown]
# ### Initialise state and covariance

# %%
# initial state x_0
initial_theta_std = np.pi
initial_theta = normalize_angles(np.random.normal(0, initial_theta_std))

x_0 = np.array([
    kitti_data.observation_states[0, 0],
    kitti_data.observation_states[1, 0],
    initial_theta
])
x_0
# Out:
# array([-25.90045852, -25.1515364 ,   0.36715767])

# %%
# covariance for initial state estimation error (Sigma_0)
P_0 = np.array([
    [obs_noise_std[0] ** 2., 0., 0.],
    [0., obs_noise_std[1] ** 2., 0.],
    [0., 0., obs_noise_std[2] ** 2.]
])
P_0
# Out:
# array([[225.       ,   0.       ,   0.       ],
#        [  0.       , 225.       ,   0.       ],
#        [  0.       ,   0.       ,   9.8696044]])

# %%
# measurement error covariance Q
Q = np.array([
    [obs_noise_std[0] ** 2., 0.],
    [0., obs_noise_std[1] ** 2.]
])
Q
# Out:
# array([[225.,   0.],
#        [  0., 225.]])

# %%
#
R = np.array([
    [input_noise_std[0] ** 2., 0., 0.],
    [0., input_noise_std[0] ** 2., 0.],
    [0., 0., input_noise_std[1] ** 2.]
])
R
# Out:
# array([[0.81  , 0.    , 0.    ],
#        [0.    , 0.81  , 0.    ],
#        [0.    , 0.    , 0.0036]])

# %% [markdown]
# ### Extended Kalman Filter

# %%
ekf_estimated_state = apply_estimation_filter(kitti_data, 'EKF', x_0, P_0, R, Q)

# %%
kitti_data.plot_estimated_data(ekf_estimated_state)

# %%
kitti_data.evaluate_filter(ekf_estimated_state)
# Out:
# {'RMSE': array([2.70801632, 2.77667458, 0.2128095 ]),
#  'MAE': array([2.1709016 , 2.21124424, 0.143183  ]),
#  'MSE': array([7.33335242, 7.7099217 , 0.04528788]),
#  'NRMSE': array([0.00397754, 0.00407839, 0.00031258]),
#  'Mean_Error': array([ 0.0934832 ,  0.30107147, -0.03457633]),
#  'Std_Error': array([2.70640228, 2.76030391, 0.20998181]),
#  'Mean_Angular_Error': -0.034576330002543655}

# %%
ukf_estimated_state = apply_estimation_filter(kitti_data, 'UKF', x_0, P_0, R, Q)

# %%
kitti_data.plot_estimated_data(ukf_estimated_state)

# %%
kitti_data.evaluate_filter(ukf_estimated_state)
# Out:
# {'RMSE': array([2.61210775, 2.85968992, 0.14118626]),
#  'MAE': array([2.09316667, 2.26785513, 0.08581629]),
#  'MSE': array([6.8231069 , 8.17782643, 0.01993356]),
#  'NRMSE': array([0.00383667, 0.00420032, 0.00020737]),
#  'Mean_Error': array([-0.05616719, -0.29655093, -0.06989347]),
#  'Std_Error': array([2.61150381, 2.84427214, 0.12267218]),
#  'Mean_Angular_Error': -0.0698934672053868}

# %% [markdown]
# ### Compare yaw angle

# %%
timestamps = kitti_data.timestamps
original_yaw_angle = kitti_data.ground_truth_states[2, :]
ekf_estimated = ekf_estimated_state[2, :]
ukf_estimated = ukf_estimated_state[2, :]

fig = plt.figure()
plt.plot(timestamps, original_yaw_angle, lw=2, label="ground-truth")
plt.plot(timestamps, ekf_estimated, marker='.', lw=0, markersize=5, alpha=0.4, label='EKF')
plt.plot(timestamps, ukf_estimated, marker='.', lw=0, markersize=5, alpha=0.4, label='UKF')
plt.xlabel('time elapsed [sec]')
plt.ylabel('yaw angle [rad]')
plt.legend()
plt.savefig('2011_09_30_0034_02.png', bbox_inches='tight')
#plt.show()

# %%
fig, axarr = plt.subplots(1, 2, figsize=(12,5))
ax = axarr[0]
ax.plot(kitti_data.ground_truth_states[0, :], kitti_data.ground_truth_states[1, :], lw=3, label='ground-truth')
ax.plot(kitti_data.observation_states[0, :], kitti_data.observation_states[1, :], lw=0, marker='.', markersize=2, alpha=0.4, label='observed')
ax.plot(ekf_estimated_state[0, :], ekf_estimated_state[1, :], linestyle='dashed', lw=1.5, alpha=0.6, label='EKF estimated trajectory', color='r')
#ax.plot(ukf_estimated_state[0, :], ukf_estimated_state[1, :], linestyle='dashed', lw=1.5, alpha=0.99, label='UKF estimated trajectory', color='g')
ax.set_xlabel('X [m]')
ax.set_ylabel('Y [m]')
#ax.set_ylim([-70, 55])
#ax.set_xlim([-350, 180])
ax.title.set_text('EKF estimation')
ax.grid()
ax.legend()

ax = axarr[1]
ax.plot(kitti_data.ground_truth_states[0, :], kitti_data.ground_truth_states[1, :], lw=3, label='ground-truth')
ax.plot(kitti_data.observation_states[0, :], kitti_data.observation_states[1, :], lw=0, marker='.', markersize=2, alpha=0.4, label='observed')
#ax.plot(ekf_estimated_state[0, :], ekf_estimated_state[1, :], linestyle='dashed', lw=1.5, alpha=0.99, label='EKF estimated trajectory', color='r')
ax.plot(ukf_estimated_state[0, :], ukf_estimated_state[1, :], linestyle='dashed', lw=1.5, alpha=0.6, label='UKF estimated trajectory', color='r')
ax.set_xlabel('X [m]')
ax.set_ylabel('Y [m]')
#ax.set_ylim([-70, 55])
#ax.set_xlim([-350, 180])
ax.title.set_text('UKF estimation')
ax.grid()
ax.legend()

plt.tight_layout()
#plt.show()
plt.savefig('2011_09_30_0034_04.png', bbox_inches='tight')
